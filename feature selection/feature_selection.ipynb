# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer

pd.options.display.max_columns = None

# %% [markdown]
# ### Select Percentile

# %%
from sklearn.feature_selection import f_classif, chi2, SelectPercentile

data = load_breast_cancer()
X = pd.DataFrame(data.data, columns=data.feature_names)
Y = data.target
print(X.shape, Y.shape)
X
# Out:
# (569, 30) (569,)
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
sele_per = SelectPercentile(score_func=f_classif, percentile=20)
X_sele = sele_per.fit_transform(X, Y)
selected = sele_per.get_support()
print(X_sele.shape, Y.shape)
# Out:
# (569, 6) (569,)

# %%
for i in range(len(X.columns)):
    if selected[i]:
        print(X.columns[i])
# Out:
# mean perimeter
# mean concave points
# worst radius
# worst perimeter
# worst area
# worst concave points
